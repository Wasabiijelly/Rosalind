# %%
with open("C:\\Users\\ABCLAB\\Rosalind\\data\\rosalind_hamm.txt",'r') as f:
    line = f.readlines()
    
print(line)
print(len(line))
# Out:
# ['...\n', '...\n']
# 2

# %%
str1 = line[0].strip('\n')
str2 = line[1]

print(str1)
print(str2)
# Out:
# ...
# ...

# %%
cnt = 0

for i in range(len(str1)):
    if str1[i] != str2[i]:
        cnt += 1
        
print(cnt)
# Out:
# 481
