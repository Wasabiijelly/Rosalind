# %%
with open("C:\\Users\\ABCLAB\\Rosalind\\data\\rosalind_rna.txt",'r') as f:
    line = f.readline()
    
print(line)
# Out:
# ...

# %%
line_transcripted = line.replace('T','U')

# %%
print(line_transcripted)
# Out:
# ...
